# %% [markdown]
# <a href="https://colab.research.google.com/github/Shumookh/GreanHeart/blob/main/GreenHeart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-----------(import library)----------#

import math
import matplotlib.pyplot as plt

#-----------(Create shape)----------#

def hearta(k):
    return 15 * math.sin(k) ** 3

def heartb(k):
    return 12 * math.cos(k) - 6 * math.cos(2 * k) - 2 * math.cos(3 * k) - math.cos(4 * k)

x = [hearta(i) * 20 for i in range(9999)]
y = [heartb(i) * 20 for i in range(9999)]

plt.fill(x, y, color="#1b5e20", alpha=0.5)

#-----------(Remove axis numbers and ticks)----------#
plt.axis('off')

#----------(Set aspect ratio to equal to maintain the shape)----------#
plt.axis('equal')

#---------(Add centered text)----------#
    # Font properties
font_properties = {
    'family': 'serif',      # (e.g., 'serif', 'sans-serif', 'monospace','Cursive', 'Fantasy', 'Script', 'Display').
    'weight': 'normal',     # (e.g.,'normal', 'bold'...)
    'size': 15              # Size of the text
}
plt.text(0, 0, 'MSc.Chem.Tech. \n Shumookh ', fontdict=font_properties, ha='center', va='center', color='white')
#----------(background color)----------#
plt.gca().set_facecolor('white')

plt.show()

# %%
#-----------(import library)----------#
import numpy as np
import matplotlib.pyplot as plt

#----------(Parametric equations for the heart shape0----------#
t = np.linspace(0, 2 * np.pi, 1000)
x = 15 * np.sin(t) ** 3
y = 12 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t)

#----------(Plotting the heart shape)----------#
plt.figure(figsize=(5, 5))
plt.plot(x, y, color="#1b5e20")
plt.fill(x, y, color="#1b5e20", alpha=0.5)

#-----------(Remove axis numbers and ticks)----------#
plt.axis('off')

#----------(Set aspect ratio to equal to maintain the shape)----------#
plt.axis('equal')

#---------(Add centered text)----------#
    # Font properties
font_properties = {
    'family': 'serif',      # (e.g., 'serif', 'sans-serif', 'monospace','Cursive', 'Fantasy', 'Script', 'Display').
    'weight': 'normal',     # (e.g.,'normal', 'bold'...)
    'size': 15              # Size of the text
}
plt.text(0, 0, 'MSc.Chem.Tech. \n Shumookh ', fontdict=font_properties, ha='center', va='center', color='white')
#----------(background color)----------#
plt.gca().set_facecolor('white')

plt.show()

# %%
#-----------(Import libraries)----------#
import math
import numpy as np
import matplotlib.pyplot as plt

#-----------(Heart shape using math)----------#
def hearta(k):
    return 15 * math.sin(k) ** 3

def heartb(k):
    return 12 * math.cos(k) - 6 * math.cos(2 * k) - 2 * math.cos(3 * k) - math.cos(4 * k)

#----------(Generate points for heart shape using math)----------#
x_math = [hearta(i) * 20 for i in range(9999)]
y_math = [heartb(i) * 20 for i in range(9999)]

#----------(Plotting the heart shape using math)----------#
plt.figure(figsize=(10, 5))

#----------(Second subplot for math heart)----------#
plt.subplot(1, 2, 1)
plt.fill(x_math, y_math, color="#1b5e20", alpha=0.5)
plt.axis('off')
plt.axis('equal')
plt.gca().set_facecolor('white')
plt.text(0, 0, 'MSc.Chem.Tech. \n Shumookh', fontdict={'family': 'serif', 'size': 15}, ha='center', va='center', color='white')
plt.title('Heart by Math')

#----------( Heart shape using numpy)----------#
t = np.linspace(0, 2 * np.pi, 1000)
x_numpy = 15 * np.sin(t) ** 3
y_numpy = 12 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t)

#----------(Second subplot for numpy heart)----------#
plt.subplot(1, 2, 2)
plt.fill(x_numpy, y_numpy, color="#1b5e20", alpha=0.5)
plt.axis('off')
plt.axis('equal')
plt.gca().set_facecolor('white')
plt.text(0, 0, 'MSc.Chem.Tech. \n Shumookh', fontdict={'family': 'serif', 'size': 15}, ha='center', va='center', color='white')
plt.title('Heart by NumPy')

plt.tight_layout()
plt.show()
